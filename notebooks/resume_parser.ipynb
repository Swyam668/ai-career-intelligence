# %%
import pdfplumber

with pdfplumber.open("../docs/Resume.pdf") as pdf:
    text = ""

    for page in pdf.pages:
        text += page.extract_text() + "\n"

print(text[:2000])
# Out:
# SWYAM VATWANI
# • GitHub • LinkedIn • +91-9799292066 • swyamv04@gmail.com • Leetcode • Jaipur, India
# SUMMARY
# Machine Learning enthusiast with practical experience in implementing and evaluating regression models
# from scratch, performing feature engineering, data preprocessing, and exploratory data analysis using Python.
# Experienced in developing AI-powered applications and applying machine learning techniques to real-world
# datasets. Passionate about building intelligent systems and continuously expanding expertise in ML and Deep
# Learning.
# EDUCATION
# Bachelor of Science in Computer Science CGPA: 9.0 Aug 2024 - May 2028
# National Institute of Technology, Delhi
# PROJECTS
# StudyGPT | AI-Powered Learning Platform
# Developed an AI-powered learning platform using Retrieval-Augmented Generation (RAG), 04/2026
# MongoDB Atlas Vector Search, Gemini Embeddings, LLM-based reranking, and a multi-model AI
# pipeline.
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python314\python.exe

# %%
KNOWN_SKILLS = [
    # Programming Languages
    "python",
    "java",
    "javascript",
    "typescript",
    "c",
    "c++",
    "c#",
    "go",
    "rust",
    "kotlin",
    "scala",
    "r",
    "matlab",
    "php",
    "ruby",
    "swift",
    "dart",
    "perl",
    "bash",
    "shell scripting",

    # Frontend
    "html",
    "css",
    "sass",
    "less",
    "react",
    "next.js",
    "vue.js",
    "nuxt.js",
    "angular",
    "svelte",
    "redux",
    "jquery",
    "tailwind css",
    "bootstrap",
    "material ui",
    "chakra ui",
    "webpack",
    "vite",

    # Backend
    "node.js",
    "express.js",
    "nestjs",
    "django",
    "flask",
    "fastapi",
    "spring boot",
    "spring",
    "hibernate",
    "asp.net",
    ".net core",
    "laravel",
    "ruby on rails",
    "gin",
    "fiber",
    "grpc",
    "rest api",
    "graphql",

    # Databases
    "sql",
    "mysql",
    "postgresql",
    "sqlite",
    "microsoft sql server",
    "oracle",
    "mongodb",
    "cassandra",
    "redis",
    "dynamodb",
    "couchbase",
    "neo4j",
    "elasticsearch",
    "opensearch",

    # Data Engineering
    "apache spark",
    "pyspark",
    "hadoop",
    "hive",
    "hbase",
    "kafka",
    "apache airflow",
    "dbt",
    "databricks",
    "etl",
    "elt",
    "data warehousing",
    "snowflake",
    "bigquery",
    "redshift",
    "data lake",
    "data modeling",

    # Data Science
    "pandas",
    "numpy",
    "scipy",
    "statsmodels",
    "matplotlib",
    "seaborn",
    "plotly",
    "jupyter",
    "statistics",
    "hypothesis testing",
    "a/b testing",
    "time series analysis",
    "forecasting",
    "feature engineering",
    "exploratory data analysis",
    "data visualization",

    # Machine Learning
    "machine learning",
    "supervised learning",
    "unsupervised learning",
    "reinforcement learning",
    "classification",
    "regression",
    "clustering",
    "xgboost",
    "lightgbm",
    "catboost",
    "scikit-learn",
    "model deployment",
    "model evaluation",
    "cross validation",
    "ensemble learning",

    # Deep Learning
    "deep learning",
    "tensorflow",
    "keras",
    "pytorch",
    "cnn",
    "rnn",
    "lstm",
    "gru",
    "transformers",
    "attention mechanisms",
    "computer vision",
    "image classification",
    "object detection",
    "semantic segmentation",

    # NLP
    "natural language processing",
    "nlp",
    "spacy",
    "nltk",
    "bert",
    "roberta",
    "gpt",
    "tokenization",
    "named entity recognition",
    "sentiment analysis",
    "text classification",
    "question answering",
    "information retrieval",

    # Generative AI / LLM
    "large language models",
    "llm",
    "prompt engineering",
    "rag",
    "retrieval augmented generation",
    "langchain",
    "langgraph",
    "llamaindex",
    "vector databases",
    "embedding models",
    "fine tuning",
    "instruction tuning",
    "agentic ai",
    "multi-agent systems",
    "openai api",
    "anthropic api",
    "gemini api",
    "mcp",
    "function calling",

    # MLOps
    "mlops",
    "mlflow",
    "kubeflow",
    "model monitoring",
    "feature stores",
    "feature pipelines",
    "experiment tracking",
    "ci/cd for ml",
    "data versioning",
    "dvc",

    # Cloud
    "aws",
    "amazon s3",
    "ec2",
    "lambda",
    "ecs",
    "eks",
    "cloudformation",
    "azure",
    "azure ml",
    "azure devops",
    "gcp",
    "vertex ai",
    "cloud run",
    "cloud functions",

    # DevOps
    "docker",
    "kubernetes",
    "terraform",
    "ansible",
    "jenkins",
    "github actions",
    "gitlab ci",
    "circleci",
    "argo cd",
    "helm",
    "prometheus",
    "grafana",
    "nginx",

    # Software Engineering
    "git",
    "github",
    "gitlab",
    "bitbucket",
    "oop",
    "design patterns",
    "system design",
    "microservices",
    "distributed systems",
    "multithreading",
    "concurrency",
    "unit testing",
    "integration testing",
    "test automation",
    "agile",
    "scrum",

    # Security
    "cybersecurity",
    "oauth",
    "jwt",
    "authentication",
    "authorization",
    "owasp",
    "penetration testing",
    "network security",
    "cryptography",

    # Data Analytics
    "power bi",
    "tableau",
    "looker",
    "excel",
    "google sheets",
    "business intelligence",
    "dashboarding",
    "reporting",
    "kpi analysis",

    # Mobile
    "android",
    "ios",
    "react native",
    "flutter",
    "xamarin",
    "jetpack compose",
    "swiftui",

    # QA
    "selenium",
    "cypress",
    "playwright",
    "postman",
    "jmeter",
    "api testing",
    "performance testing",

    # Networking
    "tcp/ip",
    "dns",
    "http",
    "https",
    "load balancing",
    "vpn",

    # Operating Systems
    "linux",
    "ubuntu",
    "windows server",
    "unix",

    # Soft Skills
    "communication",
    "leadership",
    "problem solving",
    "critical thinking",
    "teamwork",
    "project management",
    "stakeholder management",
    "mentoring",
    "presentation skills"
]

# %%
import re

def extract_skills(text):

    text = text.lower()

    found = set()

    for skill in KNOWN_SKILLS:

        pattern = r"\b" + re.escape(skill) + r"\b"

        if re.search(pattern, text):
            found.add(skill)

    return found

# %%
skills = extract_skills(text)

print(skills)
# Out:
# {'classification', 'model evaluation', 'express.js', 'c', 'llm', 'flask', 'numpy', 'java', 'machine learning', 'node.js', 'react', 'pandas', 'tailwind css', 'css', 'mysql', 'rag', 'tensorflow', 'regression', 'scikit-learn', 'python', 'mongodb', 'matplotlib', 'feature engineering', 'exploratory data analysis', 'github'}

# %%
EDUCATION = [
    "b.tech",
    "bachelor",
    "master",
    "m.tech",
    "phd",
    "mba"
]

# %%
def extract_education(text):
    text = text.lower()

    education_keywords = {
        "phd": ["phd", "doctor of philosophy"],
        "master": ["mtech", "m.tech", "msc", "m.sc", "master", "mba"],
        "bachelor": ["btech", "b.tech", "b.e", "be", "bsc", "b.sc", "bachelor"],
        "diploma": ["diploma"],
        "high_school": ["high school", "12th", "senior secondary", "intermediate"]
    }

    for level, keywords in education_keywords.items():
        for keyword in keywords:
            # word boundary to avoid false matches
            pattern = r"\b" + re.escape(keyword) + r"\b"
            if re.search(pattern, text):
                return level

    return "unknown"

# %%
def extract_experience(text):

    text = text.lower()

    patterns = [
        r"(\d+)\+?\s*years?\s*(of)?\s*experience",
        r"(\d+)\+?\s*years?\s*experience",
        r"experience\s*[:\-]?\s*(\d+)\+?\s*years?",
    ]

    for pattern in patterns:
        match = re.search(pattern, text)
        if match:
            return int(match.group(1))

    return 0

# %%
user_profile = {
    "skills": extract_skills(text),
    "education": extract_education(text),
    "experience": extract_experience(text)
}

user_profile
# Out:
# {'skills': {'c',
#   'classification',
#   'css',
#   'exploratory data analysis',
#   'express.js',
#   'feature engineering',
#   'flask',
#   'github',
#   'java',
#   'llm',
#   'machine learning',
#   'matplotlib',
#   'model evaluation',
#   'mongodb',
#   'mysql',
#   'node.js',
#   'numpy',
#   'pandas',
#   'python',
#   'rag',
#   'react',
#   'regression',
#   'scikit-learn',
#   'tailwind css',
#   'tensorflow'},
#  'education': 'bachelor',
#  'experience': 0}
